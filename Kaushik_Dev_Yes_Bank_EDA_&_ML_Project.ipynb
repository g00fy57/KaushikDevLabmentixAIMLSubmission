# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# Project Name- Yes Bank EDA & ML
#
# Project Type- EDA/
#
# Contribution-Individual
#
# By Kaushik Dev

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# Introduction
#
# This project, titled "Yes Bank EDA & ML", aims to analyze Yes Bank’s stock price data using Exploratory Data Analysis (EDA) and Machine Learning (ML) techniques. The primary objective is to gain insights into stock price movements and predict future trends using regression and classification models.
#
# Dataset Overview
#
# The dataset used is data_YesBank_StockPrices.csv.
# It includes various financial attributes related to Yes Bank’s stock prices.
# Initial data processing steps include handling missing values, duplicate records, and data type conversions.
# Exploratory Data Analysis (EDA)
#
# The project performs an in-depth EDA to understand stock price trends, distributions, and patterns. Key analyses include:
#
# Statistical Summary: Understanding key metrics like mean, median, and standard deviation.
#
# Data Visualization: Using histograms, box plots, and time-series plots to analyze stock trends.
# Correlation Analysis: Identifying relationships between different stock price indicators.
# Outlier Detection: Identifying anomalies that could impact model accuracy.
# Machine Learning Implementation
# The project explores multiple ML models for stock price prediction, including:
#
# Regression Models (e.g., Linear Regression, Random Forest Regressor)
#
# Each ML model is evaluated based on:
#
# Performance Metrics: RMSE, R-Squared (for regression)
# Cross-Validation & Hyperparameter Tuning: To optimize model performance.
# Business Impact Analysis: Interpreting how ML predictions affect trading decisions.
# Conclusion
# This project provides valuable insights into Yes Bank’s stock price movements through data analysis and predictive modeling. The results can be leveraged for stock market decision-making and investment strategies.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# https://github.com/g00fy57/KaushikDevLabmentixAIMLSubmission

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# Stock market prices fluctuate due to various factors such as market conditions, economic events, and company performance. Predicting stock prices accurately is a challenging task due to the complexity and volatility of financial markets.
#
# Yes Bank, one of India’s prominent private-sector banks, has experienced significant fluctuations in its stock prices over the years. Understanding the trends, patterns, and key influencing factors behind these fluctuations is crucial for investors, traders, and financial analysts.
#
# This project aims to perform Exploratory Data Analysis (EDA) on Yes Bank’s stock price data to identify meaningful patterns and trends. Additionally, various Machine Learning (ML) models will be implemented to predict future stock prices. The goal is to:
#
# Analyze historical stock price data to extract insights.
# Identify correlations between stock price movements and financial indicators.
# Develop predictive models to forecast future stock prices.
# Evaluate model performance using appropriate metrics and optimize results through hyperparameter tuning.
# Provide business insights that can aid investors and financial institutions in decision-making.
# Through this project, we seek to bridge the gap between data-driven insights and real-world stock market applications, ultimately helping in better investment strategies.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

# %%
df=pd.read_csv('data_YesBank_StockPrices.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

# %%
# Display the first few rows of the dataset
df.head()
# Out:
#      Date   Open   High    Low  Close
# 0  Jul-05  13.00  14.00  11.25  12.46
# 1  Aug-05  12.58  14.88  12.55  13.42
# 2  Sep-05  13.48  14.87  12.27  13.30
# 3  Oct-05  13.20  14.47  12.40  12.99
# 4  Nov-05  13.35  13.88  12.88  13.41

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

# %%
df.shape
# Out:
# (185, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    object
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.4+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

# %%
# Count the number of duplicate rows in the dataset
duplicate_count =df.duplicated().sum()
duplicate_count
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

# %%
# Visualizing the missing values

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate missing values count
missing_values = df.isnull().sum()

# Filter out columns with at least one missing value
missing_values = missing_values[missing_values > 0]

# Plot missing values
plt.figure(figsize=(12, 6))
sns.barplot(x=missing_values.index, y=missing_values.values, palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("Columns")
plt.ylabel("Missing Values Count")
plt.title("Missing Values in Dataset")
plt.show()

# Display missing values count
missing_values
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# The dataset contains 185 rows and 5 columns, tracking Yes Bank's stock prices over time. The columns are:
#
# Date (object format) – appears to be in "MMM-YY" format (e.g., "Jul-05" for July 2005).
#
# Open (float) – opening price of the stock.
#
# High (float) – highest price reached.
#
# Low (float) – lowest price reached.
#
# Close (float) – closing price of the stock.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

# %%
# Dataset Describe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    object
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.4+ KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close
# count  185.000000  185.000000  185.000000  185.000000
# mean   105.541405  116.104324   94.947838  105.204703
# std     98.879850  106.333497   91.219415   98.583153
# min     10.000000   11.240000    5.550000    9.980000
# 25%     33.800000   36.140000   28.510000   33.450000
# 50%     62.980000   72.550000   58.000000   62.540000
# 75%    153.000000  169.190000  138.350000  153.300000
# max    369.950000  404.000000  345.500000  367.900000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# Open Price
#
# Mean: 105.54
#
# Standard Deviation: 98.88
# Min: 10.00
# Max: 369.95
# Median (50th percentile): 62.98
# Range: 10.00 to 369.95
#
# High Price (Highest price reached in the period)
#
# Mean: 116.10
# Standard Deviation: 106.33
# Min: 11.24
# Max: 404.00
# Median: 72.55
#
# Low Price (Lowest price reached in the period)
#
# Mean: 94.95
# Standard Deviation: 91.22
# Min: 5.55
# Max: 345.50
# Median: 58.00
#
# Close Price (Final price at the end of the period)
#
# Mean: 105.20
# Standard Deviation: 98.58
# Min: 9.98
# Max: 367.90
# Median: 62.54
#
# The dataset captures significant fluctuations in Yes Bank’s stock prices, with a large spread between minimum and maximum values.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# %%
# Calculate the number of unique values for each column
unique_values = df.nunique()

# Display the unique values count
unique_values
# Out:
# Date     185
# Open     183
# High     184
# Low      183
# Close    185
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
# Step 1: Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%b-%y')

# Step 2: Check for missing values
missing_values = df.isnull().sum()

# Step 3: Sort data by date
df = df.sort_values(by='Date')

# Step 4: Check for duplicate rows and remove them
df = df.drop_duplicates()

# Extract Year and Month for further analysis
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month


# Step 5: Validate data types
data_types = df.dtypes

# Display results
missing_values, data_types, df.head()
# Out:
# (Date     0
#  Open     0
#  High     0
#  Low      0
#  Close    0
#  dtype: int64,
#  Date     datetime64[ns]
#  Open            float64
#  High            float64
#  Low             float64
#  Close           float64
#  Year              int32
#  Month             int32
#  dtype: object,
#          Date   Open   High    Low  Close  Year  Month
#  0 2005-07-01  13.00  14.00  11.25  12.46  2005      7
#  1 2005-08-01  12.58  14.88  12.55  13.42  2005      8
#  2 2005-09-01  13.48  14.87  12.27  13.30  2005      9
#  3 2005-10-01  13.20  14.47  12.40  12.99  2005     10
#  4 2005-11-01  13.35  13.88  12.88  13.41  2005     11)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Date Conversion: The 'Date' column is now in a proper datetime format.
#
# Missing Values: No missing values were found.
#
# Sorting: Data is now sorted chronologically.
#
# Duplicate Removal: No duplicate rows were detected.
#
# Data Type Validation: All columns have appropriate data types.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %%
# Plot Closing Price Over Time
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], label='Close Price', color='blue')
plt.xlabel("Year")
plt.ylabel("Close Price")
plt.title("Closing Price Over Time")
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# A line plot is effective in tracking trends over time. The closing price is a crucial metric for investors to understand long-term movement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# If the trend is upward, the stock is gaining investor confidence.
# If the trend is downward, it may indicate financial instability or loss of trust. There was an upwards trend until 2019, then a downwards trend likely due to the COVID-19 pandemic.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Positive Impact:
#
# Investors can time their buy/sell decisions based on trends.
#
# Companies can identify patterns and adjust their strategies.
#
# Negative Impact:
#
# A steep downward trend can scare investors away, reducing stock value.
#
# Volatility can create uncertainty, impacting institutional investments.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %%
# Scatter Plot: Open vs. Close prices
plt.figure(figsize=(8, 6))
plt.scatter(df['Open'], df['Close'], alpha=0.6, color='green')
plt.xlabel('Opening Price')
plt.ylabel('Closing Price')
plt.title('Scatter Plot: Open vs. Close Prices')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# This visualization helps identify how closely opening and closing prices are related. Large gaps indicate high volatility.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# If most points lie close to the 45-degree line, it shows stability.
# Large deviations indicate high intraday price fluctuations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Positive Impact:
#
# Traders can exploit large price differences for short-term gains.
# Companies can adjust trading strategies based on volatility.
#
# Negative Impact:
#
# High volatility can lead to panic selling among investors.
# Sharp differences might indicate market manipulation concerns.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %%
# Plot Histogram of Closing Prices
plt.figure(figsize=(12, 6))
sns.histplot(df['Close'], bins=20, kde=True, color='blue')
plt.xlabel("Closing Price")
plt.ylabel("Frequency")
plt.title("Distribution of Closing Prices")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# A histogram helps understand the most frequent price ranges, showing whether prices are normally distributed or skewed.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# If most prices fall within a narrow range, the stock is stable.
# A wide distribution suggests significant price fluctuations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Positive Impact:
#
# Helps investors predict future price behavior based on past trends.
# Useful for risk assessment and portfolio diversification.
#
# Negative Impact:
#
# If the distribution is heavily skewed, it indicates market uncertainty.
# Investors may avoid a stock with extreme price fluctuations.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %%
import seaborn as sns

# Box Plot: Stock price variations by month
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Month'], y=df['Close'], palette="coolwarm")
plt.xlabel('Month')
plt.ylabel('Closing Price')
plt.title('Stock Price Variations by Month (Box Plot)')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-36-42cf287feb4f>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Month'], y=df['Close'], palette="coolwarm")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# A box plot highlights seasonal trends and potential outliers, helping businesses plan better.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# If some months have consistently higher prices, seasonal demand may influence stock movements.
# Outliers indicate extreme market reactions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Positive Impact:
#
# Investors can plan entries and exits based on historical trends.
# Companies can predict stock performance during key months.
#
# Negative Impact:
#
# Extreme variations can deter long-term investors.
# Unexpected outliers may create confusion in the market.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %%
# Bar Chart: Average closing price per year
avg_close_per_year = df.groupby('Year')['Close'].mean()

plt.figure(figsize=(10, 6))
avg_close_per_year.plot(kind='bar', color='teal', edgecolor='black', alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Average Closing Price')
plt.title('Average Closing Price Per Year')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Yearly trends help assess long-term stock performance and company growth.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# If the average price increases annually, the company is growing.
# A declining trend may indicate financial struggles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Positive Impact:
#
# Encourages long-term investors if a steady increase is seen.
# Can boost investor confidence and brand reputation.
#
# Negative Impact:
#
# A declining trend can reduce investment inflow.
# Competitors might capitalize on weak performance.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %%
# Moving Average Plot: 3-month rolling average of closing prices
df['Rolling_Avg'] = df['Close'].rolling(window=3).mean()

plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], label='Closing Price', color='gray', alpha=0.6)
plt.plot(df['Date'], df['Rolling_Avg'], label='3-Month Moving Average', color='red', linewidth=2)
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('3-Month Moving Average of Closing Prices')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Moving averages smooth out short-term fluctuations and highlight the actual trend.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# If the rolling average is consistently increasing, the stock has positive momentum.
# If it fluctuates frequently, the stock is highly volatile.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Positive Impact:
#
# Helps investors make informed long-term decisions.
# Reduces noise from daily price fluctuations.
#
# Negative Impact:
#
# Short-term traders may misinterpret trends and make hasty decisions.
# Could mask sudden major market changes.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %%
# Violin Plot: Distribution of Closing Prices by Year
plt.figure(figsize=(12, 6))
sns.violinplot(x=df['Year'], y=df['Close'], palette="coolwarm")
plt.xlabel('Year')
plt.ylabel('Closing Price')
plt.title('Distribution of Closing Prices by Year (Violin Plot)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# <ipython-input-42-612a694c50e0>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=df['Year'], y=df['Close'], palette="coolwarm")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# A violin plot shows the probability density of stock prices over different years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# If distributions become narrower over time, the stock is stabilizing.
# If they remain wide, uncertainty in price movements continues.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Positive Impact:
#
# Investors can assess risk and returns for each year.
# Useful for predicting market behavior based on historical patterns.
#
# Negative Impact:
#
# High uncertainty can scare away long-term investors.
# If a stock price shows wide variation, institutional investors may hesitate.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %%
# Pie Chart: Percentage of months with increasing vs. decreasing prices
df['Price_Change'] = df['Close'].diff()
increasing_months = (df['Price_Change'] > 0).sum()
decreasing_months = (df['Price_Change'] < 0).sum()

plt.figure(figsize=(6, 6))
plt.pie([increasing_months, decreasing_months], labels=['Increasing', 'Decreasing'], autopct='%1.1f%%', colors=['green', 'red'], startangle=90)
plt.title('Percentage of Months with Increasing vs. Decreasing Prices')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# This helps visualize how often the stock gained vs. lost value in different months.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# A stock that gains in more months than it loses is likely a good investment.
# If losses dominate, risk increases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Positive Impact:
#
# Helps investors decide when to enter or exit the market.
# Provides a quick overview of stock performance.
#
# Negative Impact:
#
# If the losing months dominate, investors may avoid the stock.
# Over-reliance on past performance may mislead decisions.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %%
# Dual-axis Plot: Open and Close prices over time
fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.set_xlabel('Date')
ax1.set_ylabel('Opening Price', color='blue')
ax1.plot(df['Date'], df['Open'], label='Opening Price', color='blue', alpha=0.6)
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()
ax2.set_ylabel('Closing Price', color='red')
ax2.plot(df['Date'], df['Close'], label='Closing Price', color='red', alpha=0.6)
ax2.tick_params(axis='y', labelcolor='red')

fig.suptitle('Dual-axis Plot: Open and Close Prices Over Time')
fig.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# This dual-axis plot shows how opening and closing prices change over time on separate y-axes. Using two y-axes, we can compare how opening and closing prices move together.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# Large gaps between Open and Close may indicate volatility.
# A steady pattern indicates stability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Positive Impact:
#
# Helps day traders capitalize on daily trends.
# Companies can analyze investor reactions to market news.
#
# Negative Impact:
#
# Large gaps can create panic, leading to unnecessary sell-offs.
# Investors may misinterpret short-term trends as long-term patterns.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %%
# Monthly Trend Plot: Average closing price per month
avg_close_per_month = df.groupby('Month')['Close'].mean()

plt.figure(figsize=(10, 6))
avg_close_per_month.plot(kind='line', marker='o', color='purple', linestyle='-')
plt.xlabel('Month')
plt.ylabel('Average Closing Price')
plt.title('Average Closing Price Per Month')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# This monthly trend plot shows how the average closing price varies across different months. It helps understand seasonal variations in stock prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# Some months may show stronger performance, guiding investment decisions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Positive Impact:
#
# Investors can plan investments based on seasonal trends.
#
# Negative Impact:
#
# A seasonal dip might deter short-term investors.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %%
# Yearly Trend Plot: Median closing price per year
median_close_per_year = df.groupby('Year')['Close'].median()

plt.figure(figsize=(10, 6))
median_close_per_year.plot(kind='line', marker='o', color='darkorange', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Median Closing Price')
plt.title('Median Closing Price Per Year')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# The median price is more robust to outliers and reflects typical stock performance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# A rising median suggests growing stability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Positive Impact:
#
# Encourages long-term investment.
#
# Negative Impact:
#
# If the median declines, investor confidence drops.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %%
# Volatility Plot: Difference between high and low prices over time
df['Volatility'] = df['High'] - df['Low']

plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Volatility'], label='Volatility (High - Low)', color='brown', alpha=0.7)
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.title('Stock Price Volatility Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Shows price swings to understand risk levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# High volatility = more risk but more trading opportunities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Positive Impact:
#
# Attracts risk-taking investors.
#
# Negative Impact:
#
# Discourages conservative investors.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %%
# Heatmap: Correlation between stock price variables
plt.figure(figsize=(8, 6))
sns.heatmap(df[['Open', 'High', 'Low', 'Close']].corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Stock Prices')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# A heatmap visually represents the relationship between different stock metrics.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# If Open, High, Low, and Close are strongly correlated, price trends are predictable.
# Weak correlations indicate more unpredictability in the market.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %%
# Generate a pair plot using only numeric columns
sns.pairplot(df.select_dtypes(include=["float64"]))

# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# A pair plot visualizes relationships, correlations, and distributions between multiple numeric variables, helping detect patterns and outliers in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# Strong Positive Correlations – Open, High, Low, and Close prices are highly correlated, meaning stock prices move together.
#
# Linear Relationships – The scatter plots show a nearly linear relationship between these variables, confirming their dependency.
#
# Potential Outliers – A few points deviate significantly, suggesting possible price spikes or errors that may need further investigation.
#
# Right-Skewed Distributions – The histograms indicate that stock prices are skewed towards lower values, meaning more periods had lower prices than higher ones.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# Null Hypothesis (H₀): There is no significant difference between the Open and Close prices.
#
# Alternative Hypothesis (H₁): There is a significant difference between the Open and Close prices.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %%
# Perform Paired t-test for Open vs. Close prices
t_stat, p_value_ttest = stats.ttest_rel(df["Open"], df["Close"])

# Display results
{
    "Test": "Paired t-test (Open vs. Close)",
    "t-statistic": t_stat,
    "p-value": p_value_ttest,
}
# Out:
# {'Test': 'Paired t-test (Open vs. Close)',
#  't-statistic': 0.220963420803944,
#  'p-value': 0.825365920365391}

# %% [markdown]
# t-statistic: 0.221
#
# p-value: 0.825
#
# Conclusion: Since p > 0.05, we fail to reject the null hypothesis. This means there is no significant difference between Open and Close prices, suggesting they are statistically similar.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Paired t-test

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
#  A paired t-test compares two related samples, in this case, Open and Close prices for the same stock on different days. Since they are dependent variables, a paired t-test is appropriate to check if there's a significant difference between them.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# Null Hypothesis (H₀): The variance of stock prices (High - Low) remains constant over time.
#
# Alternative Hypothesis (H₁): The variance of stock prices changes significantly over time.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %%
# Compute stock price volatility as (High - Low)
volatility = df["High"] - df["Low"]
mid = len(volatility) // 2  # Split dataset into two halves

# Perform Levene’s test for equality of variance
levene_stat, p_value_levene = stats.levene(volatility[:mid], volatility[mid:])

# Display results
{
    "Test": "Levene’s Test (Volatility over time)",
    "Levene-statistic": levene_stat,
    "p-value": p_value_levene,
}
# Out:
# {'Test': 'Levene’s Test (Volatility over time)',
#  'Levene-statistic': 37.780217232405825,
#  'p-value': 4.8380935082942956e-09}

# %% [markdown]
# Levene-statistic: 37.78
# p-value: 4.84e-09 (very small)
#
# Conclusion: Since p < 0.05, we reject the null hypothesis, meaning that stock price volatility (High - Low) has significantly changed over time. This suggests that market conditions have fluctuated.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Levene's Statistical Test

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Levene’s test checks whether the variance of stock price fluctuations (High - Low) remains constant over time. Since market volatility can change, this test helps determine if the variations in stock prices differ significantly between two time periods.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# Null Hypothesis (H₀): There is no significant correlation between Open and Close prices.
#
# Alternative Hypothesis (H₁): There is a significant correlation between Open and Close prices.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %%
# Perform Pearson Correlation Test for Open vs. Close prices
corr_coeff, p_value_corr = stats.pearsonr(df["Open"], df["Close"])

# Display results
{
    "Test": "Pearson Correlation (Open vs. Close)",
    "Correlation Coefficient": corr_coeff,
    "p-value": p_value_corr,
}
# Out:
# {'Test': 'Pearson Correlation (Open vs. Close)',
#  'Correlation Coefficient': 0.9779710062230934,
#  'p-value': 1.852774505867169e-126}

# %% [markdown]
# Correlation Coefficient: 0.978
#
# p-value: 1.85e-126 (very small)
#
# Conclusion: Since p < 0.05, we reject the null hypothesis and confirm a strong positive correlation between Open and Close prices. This means they move together very closely.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Pearson Correlation Test

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
#  Pearson’s correlation measures the strength and direction of the relationship between two continuous variables. Since Open and Close prices are expected to be highly correlated, this test quantifies their association.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %%
# Check for missing values in the dataset
missing_values = df.isna().sum()

# Handle missing values by imputing with appropriate strategies
df_imputed = df.copy()
df_imputed["Open"].fillna(df["Open"].median(), inplace=True)   # Median imputation for Open prices
df_imputed["High"].fillna(df["High"].median(), inplace=True)   # Median imputation for High prices
df_imputed["Low"].fillna(df["Low"].median(), inplace=True)     # Median imputation for Low prices
df_imputed["Close"].fillna(df["Close"].median(), inplace=True) # Median imputation for Close prices

# Verify if missing values are handled
missing_values_after = df_imputed.isna().sum()

# Display before and after missing values count
missing_values, missing_values_after
# Out:
# <ipython-input-100-dadf6f3ae88f>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed["Open"].fillna(df["Open"].median(), inplace=True)   # Median imputation for Open prices
# <ipython-input-100-dadf6f3ae88f>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Before Imputation: The dataset had no missing values, so no imputation was required.
#
# After Imputation: All values remain intact, confirming there were no missing data points.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %%
# Define a function to detect outliers using the IQR method
def detect_outliers_iqr(data):
    Q1 = data.quantile(0.25)  # First quartile (25th percentile)
    Q3 = data.quantile(0.75)  # Third quartile (75th percentile)
    IQR = Q3 - Q1  # Interquartile range
    lower_bound = Q1 - 1.5 * IQR  # Lower threshold
    upper_bound = Q3 + 1.5 * IQR  # Upper threshold
    outliers = (data < lower_bound) | (data > upper_bound)  # Boolean mask for outliers
    return outliers.sum(), lower_bound, upper_bound

# Detect outliers for each stock price column
outlier_counts = {}
for col in ["Open", "High", "Low", "Close"]:
    count, lower, upper = detect_outliers_iqr(df[col])
    outlier_counts[col] = {"Outlier Count": count, "Lower Bound": lower, "Upper Bound": upper}

outlier_counts

# Function to cap outliers within the IQR range
def cap_outliers(data, lower_bound, upper_bound):
    return data.clip(lower=lower_bound, upper=upper_bound)

# Apply capping for each stock price column
df_capped = df.copy()
for col in ["Open", "High", "Low", "Close"]:
    _, lower, upper = detect_outliers_iqr(df[col])
    df_capped[col] = cap_outliers(df[col], lower, upper)

# Verify if outliers remain after capping
outlier_counts_after = {col: detect_outliers_iqr(df_capped[col])[0] for col in ["Open", "High", "Low", "Close"]}
outlier_counts_after
# Out:
# {'Open': 0, 'High': 0, 'Low': 0, 'Close': 0}

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Detect Outliers using the Interquartile Range (IQR) method.
#
# Handle Outliers by replacing extreme values with the median (winsorization) or capping them at a threshold.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# %%
# Extract numerical features from the Date column
df_encoded = df_capped.copy()
df_encoded["Year"] = df_encoded["Date"].dt.year  # Extract year
df_encoded["Month"] = df_encoded["Date"].dt.month  # Extract month

# Drop the original Date column
df_encoded.drop(columns=["Date"], inplace=True)

# Display the first few rows after encoding
df_encoded.head()
# Out:
#     Open   High    Low  Close  Year  Month  Rolling_Avg  Price_Change  \
# 0  13.00  14.00  11.25  12.46  2005      7          NaN           NaN
# 1  12.58  14.88  12.55  13.42  2005      8          NaN          0.96
# 2  13.48  14.87  12.27  13.30  2005      9    13.060000         -0.12
# 3  13.20  14.47  12.40  12.99  2005     10    13.236667         -0.31
# 4  13.35  13.88  12.88  13.41  2005     11    13.233333          0.42
#
#    Volatility
# 0        2.75
# 1        2.33
# 2        2.60
# 3        2.07
# 4        1.00

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# The only categorical column in the dataset is "Date" (which is in datetime format). Encoding it properly involves extracting meaningful numerical features. I did the following:
#
# Extract Features from the "Date" column:
#
# Year
#
# Month
#
# Converted these extracted features into numerical values.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# Not applicable in this dataset.

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Create new features
df_features = df_encoded.copy()
df_features["Daily Range"] = df_features["High"] - df_features["Low"]
df_features["Price Change"] = df_features["Close"] - df_features["Open"]
df_features["Return Percentage"] = (df_features["Close"] - df_features["Open"]) / df_features["Open"] * 100

# Apply PCA to reduce correlation among Open, High, Low, and Close
scaler = StandardScaler()
price_features = df_features[["Open", "High", "Low", "Close"]]
price_features_scaled = scaler.fit_transform(price_features)

pca = PCA(n_components=2)  # Reduce to 2 principal components
principal_components = pca.fit_transform(price_features_scaled)

# Add PCA components to the dataset
df_features["PCA1"] = principal_components[:, 0]
df_features["PCA2"] = principal_components[:, 1]

# Drop original highly correlated columns
df_final = df_features.drop(columns=["Open", "High", "Low", "Close"])

# Display the first few rows after transformation
df_final.head()
# Out:
#    Year  Month  Rolling_Avg  Price_Change  Volatility  Daily Range  \
# 0  2005      7          NaN           NaN        2.75         2.75
# 1  2005      8          NaN          0.96        2.33         2.33
# 2  2005      9    13.060000         -0.12        2.60         2.60
# 3  2005     10    13.236667         -0.31        2.07         2.07
# 4  2005     11    13.233333          0.42        1.00         1.00
#
#    Price Change  Return Percentage      PCA1      PCA2
# 0         -0.54          -4.153846 -1.907486 -0.014818
# 1          0.84           6.677266 -1.893114 -0.025430
# 2         -0.18          -1.335312 -1.890683 -0.018337
# 3         -0.21          -1.590909 -1.894928 -0.020669
# 4          0.06           0.449438 -1.892051 -0.027338

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %%
import numpy as np

# Step 1: Remove Highly Correlated Features (Threshold = 0.85)
correlation_matrix = df_final.corr()
high_corr_pairs = correlation_matrix.abs().where(np.triu(np.ones(correlation_matrix.shape), k=1) > 0.85)
drop_cols = [column for column in high_corr_pairs.columns if any(high_corr_pairs[column] > 0.85)]

# Drop highly correlated features
df_reduced = df_final.drop(columns=drop_cols)

# Step 2: Remove Low-Variance Features
selector = VarianceThreshold(threshold=0.01)  # Removing near-constant features
df_selected = df_reduced.loc[:, selector.fit(df_reduced).get_support()]

# Display selected features after statistical selection
df_selected.head(), df_selected.columns.tolist()
# Out:
# (   Year  Month  Rolling_Avg  Price_Change  Volatility  Return Percentage
#  0  2005      7          NaN           NaN        2.75          -4.153846
#  1  2005      8          NaN          0.96        2.33           6.677266
#  2  2005      9    13.060000         -0.12        2.60          -1.335312
#  3  2005     10    13.236667         -0.31        2.07          -1.590909
#  4  2005     11    13.233333          0.42        1.00           0.449438,
#  ['Year',
#   'Month',
#   'Rolling_Avg',
#   'Price_Change',
#   'Volatility',
#   'Return Percentage'])

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Remove Highly Correlated Features: If two features have high correlation (above 0.85), we dropped one.
#
# Variance Thresholding: Dropped low-variance features that contribute little information.
#
# Domain Knowledge: Selected meaningful features relevant to stock price movements.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Selected Features:
#
# Year: Captures long-term trends.
#
# Month: Accounts for seasonal effects.
#
# Volatility: Represents stock volatility.
#
# Price Change: Tracks daily price movement.
#
# Return Percentage: Shows percentage price change.
#
# Rolling Average

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %% [markdown]
# Yes, data transformation can improve model performance by making the distribution of features more suitable for analysis

# %%
# Transform Your data

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Initialize scalers
standard_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()

# Apply Min-Max Scaling to Year, Month, Rolling Average, and Volatility (Daily Range)
df_transformed["Year"] = minmax_scaler.fit_transform(df_transformed[["Year"]])
df_transformed["Month"] = minmax_scaler.fit_transform(df_transformed[["Month"]])
df_transformed["Rolling_Avg"] = minmax_scaler.fit_transform(df_transformed[["Rolling_Avg"]])
df_transformed["Volatility"] = minmax_scaler.fit_transform(df_transformed[["Volatility"]]) # Corrected the column name

# Apply Standard Scaling to Price Change & Return Percentage
df_transformed["Price_Change"] = standard_scaler.fit_transform(df_transformed[["Price_Change"]])
df_transformed["Return Percentage"] = standard_scaler.fit_transform(df_transformed[["Return Percentage"]])

# Display transformed dataset
df_transformed[["Year", "Month", "Volatility", "Price_Change", "Return Percentage", "Rolling_Avg"]].head()
# Out:
#    Year     Month  Volatility  Price_Change  Return Percentage  Rolling_Avg
# 0   0.0  0.545455    0.009571           NaN          -0.322113          NaN
# 1   0.0  0.636364    0.007274      0.046180           0.349781          NaN
# 2   0.0  0.727273    0.008750     -0.006431          -0.147269     0.006501
# 3   0.0  0.818182    0.005852     -0.015686          -0.163125     0.007015
# 4   0.0  0.909091    0.000000      0.019874          -0.036554     0.007005

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# Min Max Scaling already done in previous step.

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# Dimensionality Reduction using PCA already done in feature selection.

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming df_capped contains your features
# If not, replace with the correct DataFrame
X = df_capped[["Open", "High", "Low", "Close"]]
y = df_capped["Close"]

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA to reduce dimensionality
pca = PCA(n_components=4)  # Adjust the number of components as needed
X_pca = pca.fit_transform(X_scaled)

# Create a new DataFrame with PCA components
X_pca_df = pd.DataFrame(X_pca, columns=['PCA1', 'PCA2', 'PCA3', 'PCA4'], index=X.index)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %%
from sklearn.model_selection import train_test_split

# Now you can use X_pca_df for train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_pca_df, y, test_size=0.2, random_state=42)

# Display the shapes of the resulting datasets
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((148, 4), (37, 4), (148,), (37,))

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# I've split the dataset into training (80%) and testing (20%) sets to ensure proper model evaluation.
#
# Training Set: 148 samples (80%)
#
# Testing Set: 37 samples (20%)

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the distribution of the target variable (Close price)
plt.figure(figsize=(8,5))
sns.histplot(y, bins=30, kde=True, color="blue")
plt.xlabel("Closing Price")
plt.ylabel("Frequency")
plt.title("Distribution of Closing Prices")
plt.show()

# Check skewness of target variable
y_skewness = y.skew()
y_skewness
# Out:
# 1.2013643077449274

# %% [markdown]
# Yes the dataset is imbalanced as we can see above.

# %%
# Handling Imbalanced Dataset (If needed)

# %%
# Apply log transformation to the target variable (Closing Price)
y_log = np.log1p(y)  # log1p(x) = log(1 + x) to handle zero values safely

# Plot the transformed distribution
plt.figure(figsize=(8,5))
sns.histplot(y_log, bins=30, kde=True, color="green")
plt.xlabel("Log Transformed Closing Price")
plt.ylabel("Frequency")
plt.title("Distribution of Log-Transformed Closing Prices")
plt.show()

# Check new skewness after transformation
y_log_skewness = y_log.skew()
y_log_skewness
# Out:
# -0.013889487818761806

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
#  Applied log transformation to make the target variable more normally distributed.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np  # Import numpy if not already imported

# Initialize the Linear Regression model
lr_model = LinearRegression()

# Train the model on the training set
lr_model.fit(X_train, np.log1p(y_train))  # Using log-transformed target

# Predict on the test set
y_pred_log = lr_model.predict(X_test)

# Convert predictions back to the original scale (exponential transformation)
y_pred = np.expm1(y_pred_log)

# Evaluate model performance
r2 = r2_score(y_test, y_pred)
# Calculate RMSE manually using NumPy
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

r2, rmse
# Out:
# (0.5701899453335306, 59.87026559142275)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %% [markdown]
# Linear Regression is a supervised machine learning algorithm used to model the relationship between independent variables (features) and a dependent variable (target) by fitting a straight line.
#
# Interpretable → Shows how each feature impacts the stock price.
#
# Baseline Model → Helps compare performance before trying complex models.
#
# Fast & Efficient → Works well with smaller datasets.

# %%
# Visualizing evaluation Metric Score chart

# %%
import matplotlib.pyplot as plt

# Residuals (Errors)
residuals = y_test - y_pred

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Residual Plot
axes[0].scatter(y_pred, residuals, color="red", alpha=0.5)
axes[0].axhline(y=0, color="black", linestyle="--")
axes[0].set_xlabel("Predicted Closing Price")
axes[0].set_ylabel("Residuals (Errors)")
axes[0].set_title("Residual Plot")

# Actual vs. Predicted Plot
axes[1].scatter(y_test, y_pred, color="blue", alpha=0.5)
axes[1].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color="black", linestyle="--")  # Ideal line
axes[1].set_xlabel("Actual Closing Price")
axes[1].set_ylabel("Predicted Closing Price")
axes[1].set_title("Actual vs. Predicted Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# Residual Plot:
#
# Errors are not randomly scattered, suggesting non-linearity in the data.
# Some residuals are large, indicating potential underfitting.
#
# Actual vs. Predicted Plot:
#
# Predictions do not perfectly align with actual values.
# The model struggles with high closing prices, showing systematic bias.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge

# Initialize Ridge Regression model (L2 Regularization) with different alpha values
alpha_values = [0.01, 0.1, 1, 10, 100]
best_alpha = None
best_score = -float("inf")

# Perform cross-validation for each alpha value
for alpha in alpha_values:
    ridge_model = Ridge(alpha=alpha)
    scores = cross_val_score(ridge_model, X_train, np.log1p(y_train), cv=5, scoring="r2")  # 5-Fold CV

    avg_r2 = scores.mean()  # Average R² score across folds

    if avg_r2 > best_score:
        best_score = avg_r2
        best_alpha = alpha

# Train Ridge Regression with the best alpha
ridge_best = Ridge(alpha=best_alpha)
ridge_best.fit(X_train, np.log1p(y_train))

# Predict on test set
y_pred_log_ridge = ridge_best.predict(X_test)
y_pred_ridge = np.expm1(y_pred_log_ridge)

# Evaluate final model
r2_ridge = r2_score(y_test, y_pred_ridge)
rmse_ridge = np.sqrt(mean_squared_error(y_test, y_pred_ridge))

best_alpha, r2_ridge, rmse_ridge
# Out:
# (0.1, 0.5787450477461993, 59.271430512187806)

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# Cross-Validation: Use K-Fold (k=5) to check model stability across different data splits.
#
# Hyperparameter Tuning:
#
# Linear Regression has limited parameters, but we can use Ridge Regression (L2 Regularization) to optimize the alpha value.
#
# Evaluation Metrics: Use R² score and RMSE to compare performance.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %%
import matplotlib.pyplot as plt

# Residuals (Errors)
residuals = y_test - y_pred

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Residual Plot
axes[0].scatter(y_pred, residuals, color="red", alpha=0.5)
axes[0].axhline(y=0, color="black", linestyle="--")
axes[0].set_xlabel("Predicted Closing Price")
axes[0].set_ylabel("Residuals (Errors)")
axes[0].set_title("Residual Plot")

# Actual vs. Predicted Plot
axes[1].scatter(y_test, y_pred, color="blue", alpha=0.5)
axes[1].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color="black", linestyle="--")  # Ideal line
axes[1].set_xlabel("Actual Closing Price")
axes[1].set_ylabel("Predicted Closing Price")
axes[1].set_title("Actual vs. Predicted Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# Best Alpha: 0.1 (Optimal L2 Regularization).
#
# R² Score: 0.579 → Slight improvement from 0.570 (Linear Regression).
#
# RMSE: ₹59.27 → Similar error as before, indicating minimal improvement.

# %% [markdown]
# ### ML Model - 2

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize Random Forest Regressor with default parameters
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model on the training set
rf_model.fit(X_train, np.log1p(y_train))  # Using log-transformed target

# Predict on the test set
y_pred_log_rf = rf_model.predict(X_test)

# Convert predictions back to original scale
y_pred_rf = np.expm1(y_pred_log_rf)

# Evaluate model performance
r2_rf = r2_score(y_test, y_pred_rf)
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))

r2_rf, rmse_rf
# Out:
# (0.9879448232747389, 10.026738532942524)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %%
# Compute residuals
residuals_rf = y_test - y_pred_rf

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Residual Plot
axes[0].scatter(y_pred_rf, residuals_rf, color="red", alpha=0.5)
axes[0].axhline(y=0, color="black", linestyle="--")
axes[0].set_xlabel("Predicted Closing Price")
axes[0].set_ylabel("Residuals (Errors)")
axes[0].set_title("Residual Plot (Random Forest)")

# Actual vs. Predicted Plot
axes[1].scatter(y_test, y_pred_rf, color="blue", alpha=0.5)
axes[1].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color="black", linestyle="--")  # Ideal line
axes[1].set_xlabel("Actual Closing Price")
axes[1].set_ylabel("Predicted Closing Price")
axes[1].set_title("Actual vs. Predicted Plot (Random Forest)")

plt.tight_layout()
plt.show()

# %% [markdown]
# Residual Plot:
#
# Residuals are randomly scattered, indicating less bias.
# Some minor deviations suggest room for further tuning.
#
# Actual vs. Predicted Plot:
#
# Predictions closely align with actual values.
# Some underprediction for high stock prices, but overall a good fit.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %%
from sklearn.model_selection import GridSearchCV

# Define hyperparameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Initialize Random Forest model
rf_model_tuned = RandomForestRegressor(random_state=42)

# Perform Grid Search with Cross-Validation (cv=5)
grid_search = GridSearchCV(estimator=rf_model_tuned, param_grid=param_grid,
                           scoring='r2', cv=5, n_jobs=-1, verbose=1)
grid_search.fit(X_train, np.log1p(y_train))  # Using log-transformed target

# Get best parameters and best score
best_params = grid_search.best_params_
best_r2 = grid_search.best_score_

best_params, best_r2
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# ({'max_depth': 20,
#   'min_samples_leaf': 1,
#   'min_samples_split': 2,
#   'n_estimators': 300},
#  0.9913037246375156)

# %%
# Train the final optimized Random Forest model
rf_best = RandomForestRegressor(
    max_depth=20,
    min_samples_leaf=1,
    min_samples_split=2,
    n_estimators=300,
    random_state=42
)

# Fit model on training data
rf_best.fit(X_train, np.log1p(y_train))

# Predict on test set
y_pred_log_rf_best = rf_best.predict(X_test)

# Convert predictions back to original scale
y_pred_rf_best = np.expm1(y_pred_log_rf_best)

# Evaluate final model performance
r2_rf_best = r2_score(y_test, y_pred_rf_best)
rmse_rf_best = np.sqrt(mean_squared_error(y_test, y_pred_rf_best))

r2_rf_best, rmse_rf_best
# Out:
# (0.9891056184770675, 9.531783938801325)

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# I performed hyperparameter tuning for the Random Forest model using Grid Search Cross-Validation (GridSearchCV) to find the best combination of parameters.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %%
import matplotlib.pyplot as plt

# Compute residuals
residuals_rf_best = y_test - y_pred_rf_best

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Residual Plot
axes[0].scatter(y_pred_rf_best, residuals_rf_best, color="red", alpha=0.5)
axes[0].axhline(y=0, color="black", linestyle="--")
axes[0].set_xlabel("Predicted Closing Price")
axes[0].set_ylabel("Residuals (Errors)")
axes[0].set_title("Residual Plot (Optimized Random Forest)")

# Actual vs. Predicted Plot
axes[1].scatter(y_test, y_pred_rf_best, color="blue", alpha=0.5)
axes[1].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color="black", linestyle="--")  # Ideal line
axes[1].set_xlabel("Actual Closing Price")
axes[1].set_ylabel("Predicted Closing Price")
axes[1].set_title("Actual vs. Predicted Plot (Optimized Random Forest)")

plt.tight_layout()
plt.show()

# %% [markdown]
# Answer Here.

# %% [markdown]
# There has been a slight improvement as it can be seen above.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# R² Score (Coefficient of Determination)
# Indication: Measures how well the model explains the variance in stock prices.
#
# Business Impact:
#
# A high R² score (~0.991) means the model accurately predicts stock price movements based on historical data.
#
# Traders & investors can trust the model for short-term stock price forecasting, helping in decision-making & risk management.
#
# If R² was low, it would indicate that the model lacks predictive power, making it risky for financial decisions.
#
# RMSE (Root Mean Squared Error)
#
# Indication: Measures the average error in predictions.
#
# Business Impact:
#
# A lower RMSE means the model makes accurate predictions with minimal deviation.
#
# Helps financial analysts and traders in better planning of stock investments, avoiding large losses due to incorrect predictions.
#
# If RMSE were high, it would indicate that the model's predictions are unreliable, making it useless for investment strategies.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %%
# Import necessary libraries
import xgboost as xgb
from sklearn.metrics import r2_score, mean_squared_error

# Initialize the XGBoost Regressor
xgb_model = xgb.XGBRegressor(objective="reg:squarederror",
                             n_estimators=300,
                             learning_rate=0.1,
                             max_depth=6,
                             random_state=42)

# Train the model on the training set (using log-transformed target)
xgb_model.fit(X_train, np.log1p(y_train))

# Predict on the test set
y_pred_log_xgb = xgb_model.predict(X_test)

# Convert predictions back to the original scale
y_pred_xgb = np.expm1(y_pred_log_xgb)

# Evaluate model performance
r2_xgb = r2_score(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))

# Print results
print(f"XGBoost Model R² Score: {r2_xgb}")
print(f"XGBoost Model RMSE: {rmse_xgb}")
# Out:
# XGBoost Model R² Score: 0.9921360263486455
# XGBoost Model RMSE: 8.098301176067453

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute residuals
residuals_xgb = y_test - y_pred_xgb

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Residual Plot
sns.scatterplot(x=y_pred_xgb, y=residuals_xgb, color="red", alpha=0.5, ax=axes[0])
axes[0].axhline(y=0, color="black", linestyle="--")
axes[0].set_xlabel("Predicted Closing Price")
axes[0].set_ylabel("Residuals (Errors)")
axes[0].set_title("Residual Plot (XGBoost Model)")

# Actual vs. Predicted Plot
sns.scatterplot(x=y_test, y=y_pred_xgb, color="blue", alpha=0.5, ax=axes[1])
axes[1].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color="black", linestyle="--")  # Ideal line
axes[1].set_xlabel("Actual Closing Price")
axes[1].set_ylabel("Predicted Closing Price")
axes[1].set_title("Actual vs. Predicted Plot (XGBoost Model)")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %%
from sklearn.model_selection import GridSearchCV
import xgboost as xgb

# Define parameter grid for tuning
param_grid = {
    "n_estimators": [100, 300, 500],  # Number of trees
    "max_depth": [3, 6, 10],  # Depth of trees
    "learning_rate": [0.01, 0.1, 0.2],  # Step size shrinkage
    "subsample": [0.8, 1],  # Fraction of samples used per tree
    "colsample_bytree": [0.8, 1]  # Fraction of features used per tree
}

# Initialize the XGBoost model
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", random_state=42)

# Perform Grid Search with Cross-Validation (5-fold)
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    cv=5,  # 5-fold cross-validation
    scoring="r2",  # Optimizing for R² score
    n_jobs=-1,  # Use all available processors
    verbose=2
)

# Fit GridSearch to find the best parameters
grid_search.fit(X_train, np.log1p(y_train))  # Using log-transformed target

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Cross-Validation R² Score:", best_score)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters: {'colsample_bytree': 1, 'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.8}
# Best Cross-Validation R² Score: 0.9916408792552062

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# GridSearchCV (Grid Search with Cross-Validation) helps automate hyperparameter tuning by systematically testing different parameter combinations to find the best-performing model.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Predict on the test set using the best XGBoost model
y_pred_log_xgb_best = grid_search.best_estimator_.predict(X_test)

# Convert predictions back to the original scale
y_pred_xgb_best = np.expm1(y_pred_log_xgb_best)

# Compute residuals
residuals_xgb_best = y_test - y_pred_xgb_best

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Residual Plot
sns.scatterplot(x=y_pred_xgb_best, y=residuals_xgb_best, color="red", alpha=0.5, ax=axes[0])
axes[0].axhline(y=0, color="black", linestyle="--")
axes[0].set_xlabel("Predicted Closing Price")
axes[0].set_ylabel("Residuals (Errors)")
axes[0].set_title("Residual Plot (Optimized XGBoost Model)")

# Actual vs. Predicted Plot
sns.scatterplot(x=y_test, y=y_pred_xgb_best, color="blue", alpha=0.5, ax=axes[1])
axes[1].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color="black", linestyle="--")  # Ideal line
axes[1].set_xlabel("Actual Closing Price")
axes[1].set_ylabel("Predicted Closing Price")
axes[1].set_title("Actual vs. Predicted Plot (Optimized XGBoost Model)")

plt.tight_layout()
plt.show()

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# For the stock price prediction model, I focused on two key metrics that directly impact decision-making, risk management, and business performance:
#
# 1. R² Score (Coefficient of Determination)
#
# Why?
#
# Measures how well the model explains the variance in stock prices.
#
# A higher R² (closer to 1) indicates the model can predict trends accurately, leading to better investment strategies.
#
# Helps traders and businesses trust the model's predictions.
#
# Business Impact:
#
# High R² → Better forecasting of stock prices → Informed investment decisions.
#
# Low R² → Model lacks predictive power → Higher risk in trading strategies.
#
# 2. Root Mean Squared Error (RMSE)
#
# Why?
#
# Measures the average error between actual and predicted stock prices.
#
# Lower RMSE = More precise predictions → Essential for minimizing financial risk.
#
# RMSE is preferred over MAE because it penalizes larger errors more, which is crucial in financial forecasting.
#
# Business Impact:
#
# Low RMSE → More accurate predictions → Reduced losses in stock trading.
#
# High RMSE → Large deviations in predictions → Increased financial risk.
#
# Why These Metrics Matter for Business?
#
# Investors & Traders → Depend on high R² & low RMSE to make profitable stock trades.
#
# Risk Management → Accurate forecasting reduces financial risk & prevents losses.
#
# Portfolio Optimization → Helps in asset allocation & risk-adjusted returns.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# I chose the XG Boost Model. Why?
#
# Highest R² Score (~0.9913) → Best at explaining stock price variations.
#
# Lowest RMSE → Most accurate price predictions.
#
# Handles non-linearity well → More realistic modeling of stock market trends.
#
# Regularization (L1 & L2) prevents overfitting → Makes it reliable for unseen data.
#
# Business Impact of Choosing XGBoost
#
# Accurate stock price predictions → Better decision-making for investors.
#
# Reduced risk in trading strategies → Minimizes losses in volatile markets.
#
# Better portfolio optimization → Helps businesses allocate assets efficiently.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %%
import shap
import matplotlib.pyplot as plt

# Initialize SHAP Explainer for the best XGBoost model
explainer = shap.Explainer(grid_search.best_estimator_)

# Compute SHAP values for the test set
shap_values = explainer(X_test)

# Summary Plot (Global Feature Importance)
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test, plot_type="bar")
plt.title("Feature Importance (SHAP Values) - XGBoost")
plt.show()

# Force Plot (Local Explainability for a Single Prediction)
shap.initjs()
# Access the .values attribute of the shap_values object and select the first row
shap.force_plot(explainer.expected_value, shap_values.values[0], X_test.iloc[0]) # Access the values using .values[index]
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# The Yes Bank EDA & ML Project successfully explores historical stock price data using Exploratory Data Analysis (EDA) and applies Machine Learning (ML) models to predict future trends. Through comprehensive data visualization and statistical analysis, the project identifies key patterns, trends, and correlations influencing stock price movements.
#
# Key takeaways from the project include:
#
# Data-Driven Insights: EDA reveals fluctuations, volatility patterns, and potential factors impacting Yes Bank’s stock prices.
#
# ML Model Performance: Various models were trained and evaluated, highlighting the effectiveness of regression techniques in stock price prediction.
#
# Hyperparameter Tuning & Optimization: Improved accuracy was achieved through cross-validation and fine-tuning of model parameters.
#
# Business Impact: The insights derived can aid investors and financial analysts in making informed trading decisions and mitigating risks.
#
# While the models demonstrate promising predictive capabilities, stock prices are inherently influenced by external factors such as market sentiment, economic policies, and global events. Therefore, incorporating sentiment analysis and macroeconomic indicators could further enhance predictive accuracy.
#
# In conclusion, this project provides a strong foundation for understanding Yes Bank’s stock behavior and developing data-driven investment strategies. Future improvements could involve deep learning models, real-time data processing, and more sophisticated financial modeling techniques to enhance predictive performance.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
